# %%
from matplotlib import pyplot as plt
import numpy as np

# %%
xpoint=np.array([0,4])
ypoint=np.array([8, 25])

plt.plot(xpoint, ypoint)

# %%
x1point=np.array([3, 4, 7])
y1point=np.array([88, 25, 15])

plt.plot(x1point, y1point)

# %%
plt.show()

# %%
x = np.arange(-11, 11, 0.1)
y = np.sin(x)
# print(x)
# print(y)
plt.xlabel("")
plt.ylabel('Range of Sin function')
plt.plot(x, y)
plt.plot([-12, 12],[0, 0], 'k-', lw=1,dashes=[2, 2])
# plt.plot([0, 10], [0, 0.8], 'k-', lw=1,dashes=[2, 2])
# plt.grid()
